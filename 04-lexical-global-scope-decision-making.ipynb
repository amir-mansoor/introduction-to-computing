# %% [markdown]
# ## Scope
#
# ### Where can you see the variables

# %%
def f(x):
    y = 1
    x = x + y
    print("x =", x)
    print("p =",p)
    return x

# %%
p = 20
x = 3
y = 2
z = f(x)
print("z =",z)
print("x =",x)
print("y =",y)
# Out:
# x = 4
# p = 20
# z = 4
# x = 3
# y = 2

# %% [markdown]
# ### Let see this in tutor

# %%
y = 25
def f(x):
    print("y =",y)
    x = 25+9
       
    y = 1 # variables are global unless assign in local scope
x = 2
f(x)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[9], line 8
#       6     y = 1 # variables are global unless assign in local scope
#       7 x = 2
# ----> 8 f(x)
#
# Cell In[9], line 3, in f(x)
#       2 def f(x):
# ----> 3     print("y =",y)
#       4     x = 25+9
#       6     y = 1
#
# UnboundLocalError: cannot access local variable 'y' where it is not associated with a value

# %%
def pressure(v,t,n):
    """Compute the pressure in pascals of an ideal gas.
    Applies the ideal gas law.
    
    v -- Volume of gas, in cubic meters
    t -- absolute temperature in degrees kelvin
    n -- partcles of gas
    """
    
    k = 1.38e-23 # Boltzmann's Constant
    return n * k * t / v

# %%
pressure(10,20,30)
# Out:
# 8.28e-22

# %%
help(pressure)
# Out:
# Help on function pressure in module __main__:
#
# pressure(v, t, n)
#     Compute the pressure in pascals of an ideal gas.
#     Applies the ideal gas law.
#
#     v -- Volume of gas, in cubic meters
#     t -- absolute temperature in degrees kelvin
#     n -- partcles of gas

# %% [markdown]
# ### Compound Statements

# %% [raw]
# # Compound statements take the form
# <header>:
#     <statement>
#     <statement>
#     ...
# <separating header>:
#     <statement>
#     <statement>
#     ...
# ...

# %% [markdown]
# ### Functions are a form of compound statements

# %%
def percentage_difference(x,y):
    difference = abs(x-y)
    return 100 * difference / x

result = percentage_difference(40,50)

result
# Out:
# 25.0

# %% [markdown]
# ### Conditionals
#
# Also called branching statements. These allow you to make decisions

# %%
def absolute_value(x):
    """Compute abs value of x"""
    if x >= 0:
        return x
    else:
        return -x

# %%
absolute_value(10)
# Out:
# 10

# %%
absolute_value(-10)
# Out:
# 10

# %%
absolute_value(0)
# Out:
# 0

# %%
help(absolute_value)
# Out:
# Help on function absolute_value in module __main__:
#
# absolute_value(x)
#     Compute abs value of x
