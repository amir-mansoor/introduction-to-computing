# %% [markdown]
# ### Defining New Functions
#
# We can define the new functions using the def keyword

# %%
def square(x):
    return x*x  # Notice the indentation

# %% [markdown]
# And we *Call* this function as before

# %%
square(5)
# Out:
# 25

# %%
v = square(5)

# %%
v
# Out:
# 25

# %%
def sum_squares(x,y):
    return square(x) + square(y)

# %%
result = sum_squares(5,5)

# %%
result
# Out:
# 50

# %% [markdown]
# ### Obviously, we can call a function inside other functions as we did in sum_squares

# %%
sum_squares("a",3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 sum_squares("a",3)
#
# Cell In[10], line 2, in sum_squares(x, y)
#       1 def sum_squares(x,y):
# ----> 2     return square(x) + square(y)
#
# Cell In[1], line 2, in square(x)
#       1 def square(x):
# ----> 2     return x*x
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %% [markdown]
# ### Default Values

# %%
def sqrt(num,guess):
    print("Finding sqrt of num", num, "starting with guess", guess)

# %%
sqrt(10,1) # but we don't need to specify 1
# Out:
# Finding sqrt of num 10 starting with guess 5

# %%
def sqrt(num,guess=1):
    print("Finding sqrt of num", num, "starting with guess", guess)

# %%
sqrt(10)
# Out:
# Finding sqrt of num 10 starting with guess 1

# %%
sqrt(20,4)
# Out:
# Finding sqrt of num 20 starting with guess 4
